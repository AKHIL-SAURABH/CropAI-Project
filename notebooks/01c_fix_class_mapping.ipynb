# %%
import os
import json
from tensorflow.keras.preprocessing.image import ImageDataGenerator

BASE_DIR = "../datasets/PlantVillage/PlantVillage"   # 🔥 IMPORTANT: inner PlantVillage folder
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    BASE_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

class_indices = train_gen.class_indices
len(class_indices), list(class_indices.items())[:5]
# Out:
# Found 16516 images belonging to 15 classes.
# (15,
#  [('Pepper__bell___Bacterial_spot', 0),
#   ('Pepper__bell___healthy', 1),
#   ('Potato___Early_blight', 2),
#   ('Potato___Late_blight', 3),
#   ('Potato___healthy', 4)])

# %%
index_to_class = {v: k for k, v in class_indices.items()}

output_path = "../models/disease_class_mapping.json"
os.makedirs("../models", exist_ok=True)

with open(output_path, "w") as f:
    json.dump(index_to_class, f)

output_path
# Out:
# '../models/disease_class_mapping.json'
